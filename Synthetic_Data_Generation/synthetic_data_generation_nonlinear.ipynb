#        -0.32686598, -0.83382881,  0.30931389, -0.95288126, -0.41760428,
#        -1.04960832, -0.88034596,  0.5081037 ,  0.1888192 ,  1.65498465,
#        -1.5366089 ,  2.13171824, -0.43810426, -0.85332739,  1.52795472,
#        -0.60466185,  0.34919106,  0.59681325, -0.41539082,  1.31918163,
#         0.47984598, -0.53559678,  0.43178829,  1.66978422,  0.52569571,
#         0.27951126, -1.56152145,  0.12623084, -1.79428607, -1.27696293,
#         0.61078406, -0.35337935, -0.70705455,  1.23819158, -0.48959967,
#         1.25257571,  1.20210266, -0.18457268,  0.51877546, -0.40957223,
#         0.75771344, -1.20648684,  1.04030224, -0.43356103,  0.31673004,
#        -1.00480428, -0.66785051,  0.21576732, -1.0257148 , -0.05094566,
#        -0.99301149,  0.41034133, -0.29978666,  1.29998027,  0.75838859,
#         1.16820986, -0.6195112 ,  2.14840178, -1.43219759,  0.50256552,
#        -0.48843036,  0.69922571,  0.07020356,  0.66793494,  0.25200106,
#         0.30144413,  0.7153567 , -0.20618941,  2.16597596,  1.56087444,
#        -1.70224262,  0.07234561,  0.94618509, -1.56687279,  1.53587643,
#         0.56046296,  0.26331226, -0.78365852,  0.23129418, -0.4286621 ,
#        -0.70599154,  1.43527246, -1.65428344,  0.53883789, -1.39623548,
#         2.13789756, -0.96867543,  0.44880949, -0.24386255, -1.53293361,
#         1.13715728, -1.6224668 ,  1.09453695,  0.18245528,  1.75349535,
#         0.28796696,  0.14567195, -0.11603153, -0.40752846, -0.64101022,
#         1.52630322,  0.16514708,  0.79876126,  1.13425669,  0.20198427,
#         0.63045193, -0.19026567, -0.31939847,  1.03502111, -2.98312922,
#         0.89188069, -0.85014597, -0.39089944,  1.26473795, -0.88023561,
#        -0.39615777,  1.97631445, -1.25878704, -2.73379802,  0.2342883 ,
#        -0.37785777, -0.11635209, -0.0421106 , -1.03953065,  0.27810486,
#        -0.39368144, -0.77797686,  0.75448768, -1.2239244 ,  0.74766476,
#         1.49431619,  0.23401364, -1.0124913 ,  1.01823181, -1.64740737,
#         1.20572846, -0.53279344,  1.36630104,  1.86679489,  0.06453827,
#         0.35031322, -0.22896659, -1.35830342, -0.35532205, -0.68231982,
#        -0.09980211,  0.612503  ,  0.27755516, -0.80705956,  0.37161643,
#         0.0451804 , -0.7754131 ,  0.04258495,  1.40183508, -0.84197247,
#        -1.50653179, -1.66407857, -0.52984386, -0.68662524,  0.70067404,
#         0.75080048,  1.74619753, -0.02790952, -0.16787788,  1.09887153])

# %% [markdown]
# #Create first variable (source1) through autoregression:#
# S1(n)=0.125*√2*exp(-S1(n-1)*S1(n-1)/2) + ε1

# %%
source1 = np.zeros((1000))
import math
source1[1] = noise[1] + 10
source1[2] = noise[2] + 10
for x in range(3,1000):
  source1[x] = 0.125*math.sqrt(2)*math.exp(-source1[x-1]*source1[x-1]/2) + noise[x]


source1
np.savetxt("source1-nonlinear.csv", source1, delimiter=",")
#def oneTimeSeries(x0, x1, noise, 100):
#  noise[] = 0.95*x0 - 0.92*x0

from google.colab import files
files.download( "source1-nonlinear.csv" )

# %%
#import matplotlib.pylab as plt
import matplotlib.pyplot as plt
# plot the line
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.figure(figsize=(20,10))
plt.plot(source1)

#from matplotlib.pyplot import figure
#figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.set_size_inches(11,8)
#plot.show()
plt.show()

# %% [markdown]
# #Create variable source2 through autoregression#
#
# S2(n)=1.2*exp(-S1(n-1)*S1(n-1)/2) + ε2

# %%
source2 = np.zeros((1000))
np.set_printoptions(suppress=True)
noise2 = np.random.normal(0,1,1000)
noise2
import math
source2[1] = noise2[1]
source2[2] = noise2[2]
for x in range(3,1000):
  source2[x] = 1.2*math.exp(-source1[x-1]*source1[x-1]/2) + noise2[x]


source2
np.savetxt("source2-nonlinear.csv", source2, delimiter=",")
#def oneTimeSeries(x0, x1, noise, 100):
#  noise[] = 0.95*x0 - 0.92*x0

from google.colab import files
files.download( "source2-nonlinear.csv" )

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.figure(figsize=(20,10))
plt.plot(source2)

#from matplotlib.pyplot import figure
#figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.set_size_inches(11,8)
#plot.show()
plt.show()

# %% [markdown]
# #Create variable source3 based on autoregression source1 and source2#
# S3(n)= -1.05*exp(-S1(n-1)*S1(n-1)/2) + ε3

# %%
source3 = np.zeros((1000))
np.set_printoptions(suppress=True)
noise3 = np.random.normal(0,1,1000)
noise3
import math
source3[1] = noise3[1]
source3[2] = noise3[2]
for x in range(3,1000):
  source3[x] = -1.05*math.exp(-source1[x-1]*source1[x-1]/2) + noise3[x]


source2
np.savetxt("source3-nonlinear.csv", source3, delimiter=",")
#def oneTimeSeries(x0, x1, noise, 100):
#  noise[] = 0.95*x0 - 0.92*x0

from google.colab import files
files.download( "source3-nonlinear.csv" )

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.figure(figsize=(20,10))
plt.plot(source3)

#from matplotlib.pyplot import figure
#figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.set_size_inches(11,8)
#plot.show()
plt.show()

# %% [markdown]
# #Create variable source4 based on autoregression, and source3#
#
# S4(n)= -1.15*exp(-S1(n-1)*S1(n-1)/2) + 0.2 * √2  * exp(-S4(n-1)*S4(n-1)/2) + 1.35  * exp(-S3(n-1)*S3(n-1)/2) + ε4

# %%
source4 = np.zeros((1000))
np.set_printoptions(suppress=True)
noise4 = np.random.normal(0,1,1000)
import math
source4[1] = noise4[1] + 10
source4[2] = noise4[2] + 10
for x in range(3,1000):
  source4[x] = -1.15*math.exp(-source1[x-1]*source1[x-1]/2) + 0.2*math.sqrt(2)*math.exp(-source4[x-1]*source4[x-1]/2) + 1.35*math.exp(-source3[x-1]*source3[x-1]/2) + noise4[x]


source4
np.savetxt("source4-nonlinear.csv", source4, delimiter=",")
#def oneTimeSeries(x0, x1, noise, 100):
#  noise[] = 0.95*x0 - 0.92*x0

from google.colab import files
files.download( "source4.csv" ) 

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.figure(figsize=(20,10))
plt.plot(source4)

#from matplotlib.pyplot import figure
#figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#plt.set_size_inches(11,8)
#plot.show()
plt.show()

# %%
combined = np.vstack((source1, source2, source3, source4)).T
np.savetxt("combined-nonlinear.csv", combined, delimiter=",", fmt='%f')
from google.colab import files
files.download( "combined-nonlinear.csv" )

# %%
combined
# Out:
# array([[ 0.        ,  0.        ,  0.        ,  0.        ],
#        [ 9.89872818,  0.17661762,  0.86983607,  9.42513817],
#        [ 9.52935222,  0.05179771,  0.58346701,  9.86076418],
#        ...,
#        [ 0.00303578, -0.97802036,  1.58695382,  1.41903791],
#        [ 0.008898  ,  1.55568721, -0.85864991, -0.13929158],
#        [ 1.27564122,  0.60735737, -2.4632725 , -2.11666577]])
